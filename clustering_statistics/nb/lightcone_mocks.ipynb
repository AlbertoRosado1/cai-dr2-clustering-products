# %%
from pathlib import Path
from mpytools import Catalog

dirname = Path('/dvs_ro/cfs/cdirs/desi/mocks/cai/abacus_HF_lightcones/DR2/mock_catalogs/qso_base')

# %%
data = Catalog.read(dirname / 'v1.9dv' / 'QSO_AbacusSummit_base_c000_ph001_base_cmaes_opt_0_fit_DESI_nz_data.fits')
randoms = Catalog.read(dirname / 'v1.9dv' / 'QSO_AbacusSummit_base_c000_ph001_base_cmaes_opt_0_fit_DESI_nz_randoms_shuffled.fits')

# %%
data, randoms
# Out:
# (Catalog(csize=248130, size=248130, columns=['RA', 'DEC', 'Z', 'WEIGHT_FKP']),
#  Catalog(csize=24818377, size=24818377, columns=['RA', 'DEC', 'Z', 'WEIGHT_FKP']))
